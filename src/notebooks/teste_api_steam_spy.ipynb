# %%
import requests

# %%
response = requests.get(f"https://steamspy.com/api.php?request=appdetails&appid={1687950}")

# %%
response.json()
# Out:
# {'appid': 1687950,
#  'name': 'Persona 5 Royal',
#  'developer': 'ATLUS',
#  'publisher': 'SEGA',
#  'score_rank': '',
#  'positive': 95134,
#  'negative': 3289,
#  'userscore': 0,
#  'owners': '1,000,000 .. 2,000,000',
#  'average_forever': 4716,
#  'average_2weeks': 468,
#  'median_forever': 5849,
#  'median_2weeks': 623,
#  'price': '5999',
#  'initialprice': '5999',
#  'discount': '0',
#  'ccu': 6443,
#  'languages': 'English, French, Italian, German, Spanish - Spain, Japanese, Korean, Simplified Chinese, Traditional Chinese',
#  'genre': 'RPG',
#  'tags': {'JRPG': 1008,
#   'Story Rich': 812,
#   'Great Soundtrack': 798,
#   'Turn-Based Combat': 797,
#   'Anime': 759,
#   'RPG': 629,
#   'Singleplayer': 581,
#   'Party-Based RPG': 555,
#   'Dating Sim': 551,
#   'Multiple Endings': 486,
#   'Turn-Based Strategy': 464,
#   'Emotional': 459,
#   'Visual Novel': 427,
#   'Sexual Content': 407,
#   'Colorful': 392,
#   'Adventure': 310,
#   'Heist': 264,
#   'Soundtrack': 238,
# ...

# %%
response.json()
# Out:
# {'appid': 1687950,
#  'name': 'Persona 5 Royal',
#  'developer': 'ATLUS',
#  'publisher': 'SEGA',
#  'score_rank': '',
#  'positive': 94670,
#  'negative': 3276,
#  'userscore': 0,
#  'owners': '1,000,000 .. 2,000,000',
#  'average_forever': 2754,
#  'average_2weeks': 145,
#  'median_forever': 1796,
#  'median_2weeks': 145,
#  'price': '5999',
#  'initialprice': '5999',
#  'discount': '0',
#  'ccu': 9048,
#  'languages': 'English, French, Italian, German, Spanish - Spain, Japanese, Korean, Simplified Chinese, Traditional Chinese',
#  'genre': 'RPG',
#  'tags': {'JRPG': 1003,
#   'Story Rich': 809,
#   'Great Soundtrack': 794,
#   'Turn-Based Combat': 792,
#   'Anime': 756,
#   'RPG': 629,
#   'Singleplayer': 578,
#   'Party-Based RPG': 554,
#   'Dating Sim': 551,
#   'Multiple Endings': 485,
#   'Turn-Based Strategy': 463,
#   'Emotional': 458,
#   'Visual Novel': 427,
#   'Sexual Content': 404,
#   'Colorful': 392,
#   'Adventure': 310,
#   'Heist': 264,
#   'Soundtrack': 238,
# ...
